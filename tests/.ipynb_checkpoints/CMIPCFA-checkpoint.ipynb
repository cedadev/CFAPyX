# %%
# %%time
import xarray as xr
cfafile = '../testfiles/ScenarioMIP.nca'
ds = xr.open_dataset(cfafile,engine='CFA')

h1 = ds['huss'].sel(lat=slice(-60,0), lon=slice(80,180)).isel(time=slice(10000,12000)).mean(dim='time')
h1.plot()
# Out:
# /home/users/dwest77/Documents/CFAPyX/xarray_repos/xarray_loc/xarray/backends/plugins.py:80: RuntimeWarning: Engine 'kerchunk' loading failed:
# No module named 'fsspec'
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)
# Post-processed Extent: (slice(10000, 12000, None), slice(21, 64, None), slice(57, 129, None))
# CPU times: user 2.97 s, sys: 1.37 s, total: 4.34 s
# Wall time: 3.7 s

# %%
ds['huss']
# Out:
# <xarray.DataArray 'huss' (time: 251288, lat: 128, lon: 256)> Size: 33GB
# [8234205184 values with dtype=float32]
# Coordinates:
#   * time     (time) float64 2MB 6.027e+04 6.027e+04 ... 9.168e+04 9.168e+04
#   * lat      (lat) float64 1kB -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 2kB 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
# Attributes: (12/13)
#     description:         This is sampled synoptically.
#     history:             none
#     online_operation:    instant
#     interval_operation:  900 s
#     interval_write:      3 h
#     _FillValue:          1e+20
#     ...                  ...
#     standard_name:       specific_humidity
#     long_name:           Near-Surface Specific Humidity
#     units:               1
#     cell_measures:       area: areacella
#     coordinates:         height
#     cell_methods:        area: mean time: point
